# %%
# ==============================================================
# CELL 1 – Setup
# ==============================================================
import os
import sys
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader, Dataset
from torch.optim import AdamW
from tqdm import tqdm

# --- PARAMETRI AMBIENTE HPC ---
DATA_PATH = os.environ.get('DATA_PATH', 'data/PreTrain/SUPER_PRETRAIN_500pt.npz')
OUTPUT_DIR = os.environ.get('OUTPUT_DIR', 'experiments/smae_pretrain/500_pt/exp_1/')
EPOCHS = int(os.environ.get('EPOCHS', '50'))
os.makedirs(OUTPUT_DIR, exist_ok=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
print(f'PyTorch: {torch.__version__}')
torch.manual_seed(42)
np.random.seed(42)
print(f'Dati da caricare: {DATA_PATH}')
print(f'Output dir: {OUTPUT_DIR}')
print(f'Epoche: {EPOCHS}')
# Out:
# Device: cuda
# PyTorch: 2.8.0+cu128
# Dati da caricare: data/PreTrain/1000_pt/FingerPrint/Min-Max/SUPER_PRETRAIN_1000pt.npz
# Output dir: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8
# Epoche: 200

# %%
# ==========================================
# CELL 2: DATASET DEFINITION
# ==========================================
class RamanPretrainDataset(Dataset):
    def __init__(self, data_path):
        super().__init__()
        print(f"Opening file: {data_path}")
        if data_path.endswith('.mat'):
            import h5py
            with h5py.File(data_path, 'r') as f:
                self.X = np.array(f['X_SUPER_PRETRAIN']).T.astype(np.float32)
                if 'dataset_source' in f:
                    self.sources = np.array(f['dataset_source']).flatten().astype(np.int64)
                else:
                    self.sources = np.zeros(len(self.X), dtype=np.int64)
        else:
            loaded_data = np.load(data_path)
            self.X = loaded_data['X_SUPER_PRETRAIN'].astype(np.float32)
            if 'dataset_source' in loaded_data:
                self.sources = loaded_data['dataset_source'].flatten().astype(np.int64)
            else:
                self.sources = np.zeros(len(self.X), dtype=np.int64)
        print(f"Data loaded. Total spectra: {self.X.shape[0]}")

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx]).unsqueeze(0), self.sources[idx]

dataset = RamanPretrainDataset(DATA_PATH)
train_loader = DataLoader(dataset, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
# Out:
# Opening file: data/PreTrain/1000_pt/FingerPrint/Min-Max/SUPER_PRETRAIN_1000pt.npz
# Data loaded. Total spectra: 331249

# %%
# ==============================================================
# CELL 3 - Import SpectraMAENet & Build Model
# ==============================================================
import os
import sys
import torch

# Usa il file locale invece di scaricarlo da GitHub
sys.path.append('./src/models/transformer')
from Spectra_MAE import MaskedAutoencoderViT

# -----------------------------------------------------------
# 3. Hyperparameters
# -----------------------------------------------------------
SPECTRA_SIZE   = 1000
PATCH_SIZE     = 100
ENCODER_DIM    = 256
ENCODER_DEPTH  = 8
ENCODER_HEADS  = 8
DIM_MLP        = 512
DECODER_DIM    = 128
DECODER_DEPTH  = 1
DECODER_HEADS  = 8
MASK_RATIO     = 0.75

def build_smae():
    return MaskedAutoencoderViT(
        spectra_size       = SPECTRA_SIZE,
        patch_size         = PATCH_SIZE,
        encoder_dim        = ENCODER_DIM,
        depth              = ENCODER_DEPTH,
        num_heads          = ENCODER_HEADS,
        dim_mlp            = DIM_MLP,
        decoder_embed_dim  = DECODER_DIM,
        decoder_depth      = DECODER_DEPTH,
        decoder_num_heads  = DECODER_HEADS,
        norm_pix_loss      = False,
    ).to(device)

print("Building the SMAE model...")
model = build_smae()

x_test = torch.randn(4, 1, SPECTRA_SIZE).to(device)
loss_test, _, _ = model(x_test, mask_ratio=MASK_RATIO)

n_params  = sum(p.numel() for p in model.parameters())
n_patches = SPECTRA_SIZE // PATCH_SIZE

print("\n--------------------------------------------------")
print(f'Total Parameters: {n_params:,}')
print(f'Total Patches:    {n_patches}  ({SPECTRA_SIZE} / {PATCH_SIZE})')
print(f'Test Loss:        {loss_test.item():.5f}')
print("--------------------------------------------------")
# Out:
# /home/y222/y222446/.local/lib/python3.9/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Building the SMAE model...
# --------------------------------------------------
# Total Parameters: 4,485,604
# Total Patches:    10  (1000 / 100)
# Test Loss:        2.08752
# --------------------------------------------------

# %%
# ==============================================================
# CELL 4: RECONSTRUCTION VISUALIZER & SAVER
# ==============================================================
import os
import matplotlib.pyplot as plt
import torch

# Mappa le etichette ai nomi dei dataset originari
SOURCE_MAP = {
    1: 'TropHY',
    2: 'DeepR (Noisy)',
    3: 'CELLS',
    4: 'TWIST',
    5: 'IMMUNO'
}

def visualize_progress(model, fixed_batch, fixed_sources, device, epoch):
    import os
    import matplotlib.pyplot as plt
    import numpy as np
    import torch

    PLOT_DIR = OUTPUT_DIR
    os.makedirs(PLOT_DIR, exist_ok=True)

    model.eval()
    batch = fixed_batch.to(device)

    with torch.no_grad():
        loss, pred, mask = model(batch, mask_ratio=MASK_RATIO)

    # Shapes:
    # batch -> (B, 1, 500)
    # pred  -> (B, num_patches, patch_size)
    # mask  -> (B, num_patches)

    orig = batch.cpu().squeeze(1).numpy()   # (B, 500)
    pred = pred.cpu().numpy()               # (B, 20, 25)
    mask = mask.cpu().numpy()               # (B, 20)
    sources = fixed_sources.cpu().numpy()

    num_samples = len(orig)
    plt.figure(figsize=(14, 3.5 * num_samples))

    for i in range(num_samples):
        x_orig = orig[i].copy()
        x_recon = x_orig.copy()

        ax = plt.subplot(num_samples, 1, i + 1)

        # Rebuild the final spectrum:
        # replace ONLY masked patches with decoder predictions
        for p, is_masked in enumerate(mask[i]):
            start = p * PATCH_SIZE
            end = start + PATCH_SIZE

            if is_masked:
                x_recon[start:end] = pred[i, p]

                # Highlight masked regions on the plot
                ax.axvspan(start, end, color='khaki', alpha=0.35)

        # Plot original and reconstruction
        ax.plot(x_orig, label='Original Spectrum', color='royalblue', alpha=0.8)
        ax.plot(x_recon, label='MAE Reconstruction', color='red', linestyle='--', linewidth=1.5)

        # Recupera il nome del dataset originario
        source_name = SOURCE_MAP.get(int(sources[i]), "Unknown")

        if i == 0:
            ax.set_title(f'Reconstruction Progress – Epoch {epoch} | Source: {source_name}', fontsize=14)
        else:
            ax.set_title(f'Source: {source_name}', fontsize=14)

        ax.set_xlabel('Spectral Point Index')
        ax.set_ylabel('Intensity (L2-normalized)')
        ax.grid(True, alpha=0.3)
        ax.legend(loc='upper right')

    plt.tight_layout()

    save_path = os.path.join(PLOT_DIR, f'Reconstruction_Epoch_{epoch:03d}.png')
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

    print(f'📸 Plot saved successfully to: {save_path}')

    model.train()

# %%
# ==============================================================
# HELPER FUNCTION – Masked Cosine Similarity
#
# OBJECTIVE:
#   Compute cosine similarity ONLY on the MASKED regions,
#   because the MAE is trained to reconstruct the hidden patches.
#
# WHY:
#   Using cosine on the full spectrum can be misleading, because
#   it also includes visible regions that the model did not need
#   to reconstruct.
# ==============================================================

import torch

def masked_cosine_similarity(target, pred, mask, patch_size, eps=1e-8):
    """
    Computes cosine similarity ONLY on masked regions.

    Args:
        target: Tensor of shape (B, 1, 500) or (B, 500)
        pred:   Tensor of shape (B, num_patches, patch_size)
        mask:   Tensor of shape (B, num_patches), where 1 = masked patch
        patch_size: number of spectral points per patch
        eps: numerical stability constant

    Returns:
        Mean cosine similarity over the batch
    """

    # Remove channel dimension if needed: (B, 1, 500) -> (B, 500)
    if target.dim() == 3:
        target = target.squeeze(1)

    # Flatten decoder predictions: (B, num_patches, patch_size) -> (B, 500)
    pred_flat = pred.flatten(1)

    # Expand patch mask to point-level mask: (B, 20) -> (B, 500)
    mask_expanded = mask.unsqueeze(-1).repeat(1, 1, patch_size).flatten(1).float()

    # Keep only masked regions
    target_masked = target * mask_expanded
    pred_masked   = pred_flat * mask_expanded

    # Manual cosine similarity for numerical stability
    dot_product = (target_masked * pred_masked).sum(dim=1)
    target_norm = target_masked.norm(dim=1)
    pred_norm   = pred_masked.norm(dim=1)

    cos_sim = dot_product / (target_norm * pred_norm + eps)

    return cos_sim.mean()

# %%
# ==============================================================
# CELL 5 – Pre-Training SMAE Loop
# ==============================================================

import os
import torch
import torch.nn.functional as F
import numpy as np

# Path to save the final Foundation Model weights
PATH_PRETRAINED = os.path.join(OUTPUT_DIR, 'smae_pretrained_model.pth')
os.makedirs(os.path.dirname(PATH_PRETRAINED), exist_ok=True)

# Learning rate for pre-training
PRETRAIN_LR     = 1e-4

# --------------------------------------------------------------
# PREPARATION OF A FIXED BATCH FOR VISUALIZATION
# We select 1 spectrum from TropHY (1), 1 from DeepR (2) and 1 from TWIST (4)
# --------------------------------------------------------------
print("Selecting fixed spectra for visualization...")
fixed_indices = []
desired_sources = [1, 2, 4] # Ensure we include DeepR (2)

for target_src in desired_sources:
    # Find the first index in the dataset for this source
    idx = np.where(dataset.sources == target_src)[0]
    if len(idx) > 0:
        fixed_indices.append(idx[0])

# Build the fixed tensors for visualization
fixed_batch_list = []
fixed_sources_list = []
for idx in fixed_indices:
    x, y = dataset[idx]
    fixed_batch_list.append(x)
    fixed_sources_list.append(torch.tensor(y))

fixed_batch = torch.stack(fixed_batch_list)
fixed_sources = torch.stack(fixed_sources_list)
print(f"Fixed spectra ready! Sources: {[int(s) for s in fixed_sources]}")


print(f'\nStarting Pre-training for {EPOCHS} epochs...\n')

optimizer_pre = torch.optim.AdamW(model.parameters(), lr=PRETRAIN_LR, weight_decay=1e-4)
scheduler_pre = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_pre, T_max=EPOCHS)

# Tracking both metrics
pretrain_losses = []
pretrain_cos_sims = []

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0.0
    total_cos_sim = 0.0

    # NOTE: The DataLoader now returns (spectrum, source)
    # We loop directly over train_loader to avoid tqdm spam on HPC logs
    for batch_data, batch_sources in train_loader:
        batch_data = batch_data.to(device)

        optimizer_pre.zero_grad()

        # Forward pass
        loss, pred, mask = model(batch_data, mask_ratio=MASK_RATIO)

        # ----------------------------------------------------------
        # CORRECT COSINE SIMILARITY:
        # ----------------------------------------------------------
        cos_sim = masked_cosine_similarity(
            target=batch_data,
            pred=pred,
            mask=mask,
            patch_size=PATCH_SIZE
        )

        # Backward pass and optimization
        loss.backward()
        optimizer_pre.step()

        total_loss += loss.item()
        total_cos_sim += cos_sim.item()

    # Calculate averages for the entire epoch
    avg_loss = total_loss / len(train_loader)
    avg_cos_sim = total_cos_sim / len(train_loader)

    pretrain_losses.append(avg_loss)
    pretrain_cos_sims.append(avg_cos_sim)
    scheduler_pre.step()

    # Print metrics to screen at EVERY epoch to monitor progress (replaces tqdm)
    print(f'Epoch {epoch:3d}/{EPOCHS} | MSE Loss: {avg_loss:.6f} | Masked Cosine Sim: {avg_cos_sim:.4f}')
    
    # Visualize plots using our FIXED SPECTRA every 10 epochs (and the 1st epoch)
    if epoch == 1 or epoch % 50 == 0:
        visualize_progress(model, fixed_batch, fixed_sources, device, epoch)

# Final save of the Foundation Model weights
torch.save(model.state_dict(), PATH_PRETRAINED)
print(f'\n✅ Pre-trained foundation weights successfully saved -> {PATH_PRETRAINED}')
# Out:
# Selecting fixed spectra for visualization...
# Fixed spectra ready! Sources: [1, 2, 4]
#
# Starting Pre-training for 200 epochs...
# Epoch   1/200 | MSE Loss: 0.038559 | Masked Cosine Sim: 0.8746
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_001.png
# Epoch   2/200 | MSE Loss: 0.015436 | Masked Cosine Sim: 0.9489
# Epoch   3/200 | MSE Loss: 0.011710 | Masked Cosine Sim: 0.9639
# Epoch   4/200 | MSE Loss: 0.010846 | Masked Cosine Sim: 0.9673
# Epoch   5/200 | MSE Loss: 0.010518 | Masked Cosine Sim: 0.9685
# Epoch   6/200 | MSE Loss: 0.010326 | Masked Cosine Sim: 0.9693
# Epoch   7/200 | MSE Loss: 0.010183 | Masked Cosine Sim: 0.9698
# Epoch   8/200 | MSE Loss: 0.010075 | Masked Cosine Sim: 0.9702
# Epoch   9/200 | MSE Loss: 0.009989 | Masked Cosine Sim: 0.9704
# Epoch  10/200 | MSE Loss: 0.009907 | Masked Cosine Sim: 0.9707
# Epoch  11/200 | MSE Loss: 0.009859 | Masked Cosine Sim: 0.9709
# Epoch  12/200 | MSE Loss: 0.009801 | Masked Cosine Sim: 0.9711
# Epoch  13/200 | MSE Loss: 0.009748 | Masked Cosine Sim: 0.9713
# Epoch  14/200 | MSE Loss: 0.009712 | Masked Cosine Sim: 0.9714
# Epoch  15/200 | MSE Loss: 0.009644 | Masked Cosine Sim: 0.9716
# Epoch  16/200 | MSE Loss: 0.009619 | Masked Cosine Sim: 0.9717
# Epoch  17/200 | MSE Loss: 0.009601 | Masked Cosine Sim: 0.9718
# Epoch  18/200 | MSE Loss: 0.009560 | Masked Cosine Sim: 0.9719
# Epoch  19/200 | MSE Loss: 0.009534 | Masked Cosine Sim: 0.9720
# Epoch  20/200 | MSE Loss: 0.009522 | Masked Cosine Sim: 0.9720
# Epoch  21/200 | MSE Loss: 0.009480 | Masked Cosine Sim: 0.9722
# Epoch  22/200 | MSE Loss: 0.009471 | Masked Cosine Sim: 0.9722
# Epoch  23/200 | MSE Loss: 0.009445 | Masked Cosine Sim: 0.9723
# Epoch  24/200 | MSE Loss: 0.009463 | Masked Cosine Sim: 0.9722
# Epoch  25/200 | MSE Loss: 0.009423 | Masked Cosine Sim: 0.9724
# Epoch  26/200 | MSE Loss: 0.009404 | Masked Cosine Sim: 0.9724
# Epoch  27/200 | MSE Loss: 0.009406 | Masked Cosine Sim: 0.9724
# Epoch  28/200 | MSE Loss: 0.009383 | Masked Cosine Sim: 0.9725
# Epoch  29/200 | MSE Loss: 0.009365 | Masked Cosine Sim: 0.9726
# Epoch  30/200 | MSE Loss: 0.009362 | Masked Cosine Sim: 0.9726
# Epoch  31/200 | MSE Loss: 0.009351 | Masked Cosine Sim: 0.9726
# Epoch  32/200 | MSE Loss: 0.009334 | Masked Cosine Sim: 0.9727
# Epoch  33/200 | MSE Loss: 0.009329 | Masked Cosine Sim: 0.9727
# Epoch  34/200 | MSE Loss: 0.009320 | Masked Cosine Sim: 0.9727
# Epoch  35/200 | MSE Loss: 0.009296 | Masked Cosine Sim: 0.9727
# Epoch  36/200 | MSE Loss: 0.009307 | Masked Cosine Sim: 0.9728
# Epoch  37/200 | MSE Loss: 0.009290 | Masked Cosine Sim: 0.9728
# Epoch  38/200 | MSE Loss: 0.009272 | Masked Cosine Sim: 0.9728
# Epoch  39/200 | MSE Loss: 0.009292 | Masked Cosine Sim: 0.9728
# Epoch  40/200 | MSE Loss: 0.009271 | Masked Cosine Sim: 0.9729
# Epoch  41/200 | MSE Loss: 0.009280 | Masked Cosine Sim: 0.9728
# Epoch  42/200 | MSE Loss: 0.009259 | Masked Cosine Sim: 0.9729
# Epoch  43/200 | MSE Loss: 0.009253 | Masked Cosine Sim: 0.9729
# Epoch  44/200 | MSE Loss: 0.009257 | Masked Cosine Sim: 0.9729
# Epoch  45/200 | MSE Loss: 0.009244 | Masked Cosine Sim: 0.9730
# Epoch  46/200 | MSE Loss: 0.009241 | Masked Cosine Sim: 0.9730
# Epoch  47/200 | MSE Loss: 0.009231 | Masked Cosine Sim: 0.9730
# Epoch  48/200 | MSE Loss: 0.009217 | Masked Cosine Sim: 0.9730
# Epoch  49/200 | MSE Loss: 0.009221 | Masked Cosine Sim: 0.9730
# Epoch  50/200 | MSE Loss: 0.009214 | Masked Cosine Sim: 0.9730
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_050.png
# Epoch  51/200 | MSE Loss: 0.009214 | Masked Cosine Sim: 0.9730
# Epoch  52/200 | MSE Loss: 0.009226 | Masked Cosine Sim: 0.9730
# Epoch  53/200 | MSE Loss: 0.009186 | Masked Cosine Sim: 0.9731
# Epoch  54/200 | MSE Loss: 0.009187 | Masked Cosine Sim: 0.9731
# Epoch  55/200 | MSE Loss: 0.009194 | Masked Cosine Sim: 0.9731
# Epoch  56/200 | MSE Loss: 0.009193 | Masked Cosine Sim: 0.9731
# Epoch  57/200 | MSE Loss: 0.009170 | Masked Cosine Sim: 0.9732
# Epoch  58/200 | MSE Loss: 0.009179 | Masked Cosine Sim: 0.9731
# Epoch  59/200 | MSE Loss: 0.009180 | Masked Cosine Sim: 0.9731
# Epoch  60/200 | MSE Loss: 0.009162 | Masked Cosine Sim: 0.9732
# Epoch  61/200 | MSE Loss: 0.009157 | Masked Cosine Sim: 0.9732
# Epoch  62/200 | MSE Loss: 0.009164 | Masked Cosine Sim: 0.9732
# Epoch  63/200 | MSE Loss: 0.009145 | Masked Cosine Sim: 0.9733
# Epoch  64/200 | MSE Loss: 0.009149 | Masked Cosine Sim: 0.9732
# Epoch  65/200 | MSE Loss: 0.009163 | Masked Cosine Sim: 0.9732
# Epoch  66/200 | MSE Loss: 0.009136 | Masked Cosine Sim: 0.9733
# Epoch  67/200 | MSE Loss: 0.009142 | Masked Cosine Sim: 0.9733
# Epoch  68/200 | MSE Loss: 0.009142 | Masked Cosine Sim: 0.9733
# Epoch  69/200 | MSE Loss: 0.009132 | Masked Cosine Sim: 0.9733
# Epoch  70/200 | MSE Loss: 0.009131 | Masked Cosine Sim: 0.9733
# Epoch  71/200 | MSE Loss: 0.009132 | Masked Cosine Sim: 0.9733
# Epoch  72/200 | MSE Loss: 0.009125 | Masked Cosine Sim: 0.9733
# Epoch  73/200 | MSE Loss: 0.009117 | Masked Cosine Sim: 0.9734
# Epoch  74/200 | MSE Loss: 0.009124 | Masked Cosine Sim: 0.9733
# Epoch  75/200 | MSE Loss: 0.009116 | Masked Cosine Sim: 0.9734
# Epoch  76/200 | MSE Loss: 0.009110 | Masked Cosine Sim: 0.9734
# Epoch  77/200 | MSE Loss: 0.009107 | Masked Cosine Sim: 0.9733
# Epoch  78/200 | MSE Loss: 0.009100 | Masked Cosine Sim: 0.9734
# Epoch  79/200 | MSE Loss: 0.009090 | Masked Cosine Sim: 0.9734
# Epoch  80/200 | MSE Loss: 0.009095 | Masked Cosine Sim: 0.9734
# Epoch  81/200 | MSE Loss: 0.009100 | Masked Cosine Sim: 0.9734
# Epoch  82/200 | MSE Loss: 0.009082 | Masked Cosine Sim: 0.9734
# Epoch  83/200 | MSE Loss: 0.009094 | Masked Cosine Sim: 0.9734
# Epoch  84/200 | MSE Loss: 0.009097 | Masked Cosine Sim: 0.9734
# Epoch  85/200 | MSE Loss: 0.009087 | Masked Cosine Sim: 0.9734
# Epoch  86/200 | MSE Loss: 0.009088 | Masked Cosine Sim: 0.9734
# Epoch  87/200 | MSE Loss: 0.009081 | Masked Cosine Sim: 0.9734
# Epoch  88/200 | MSE Loss: 0.009066 | Masked Cosine Sim: 0.9735
# Epoch  89/200 | MSE Loss: 0.009076 | Masked Cosine Sim: 0.9735
# Epoch  90/200 | MSE Loss: 0.009076 | Masked Cosine Sim: 0.9735
# Epoch  91/200 | MSE Loss: 0.009070 | Masked Cosine Sim: 0.9735
# Epoch  92/200 | MSE Loss: 0.009072 | Masked Cosine Sim: 0.9735
# Epoch  93/200 | MSE Loss: 0.009064 | Masked Cosine Sim: 0.9735
# Epoch  94/200 | MSE Loss: 0.009058 | Masked Cosine Sim: 0.9735
# Epoch  95/200 | MSE Loss: 0.009058 | Masked Cosine Sim: 0.9735
# Epoch  96/200 | MSE Loss: 0.009049 | Masked Cosine Sim: 0.9735
# Epoch  97/200 | MSE Loss: 0.009056 | Masked Cosine Sim: 0.9735
# Epoch  98/200 | MSE Loss: 0.009050 | Masked Cosine Sim: 0.9735
# Epoch  99/200 | MSE Loss: 0.009055 | Masked Cosine Sim: 0.9735
# Epoch 100/200 | MSE Loss: 0.009043 | Masked Cosine Sim: 0.9735
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_100.png
# Epoch 101/200 | MSE Loss: 0.009038 | Masked Cosine Sim: 0.9736
# Epoch 102/200 | MSE Loss: 0.009046 | Masked Cosine Sim: 0.9736
# Epoch 103/200 | MSE Loss: 0.009029 | Masked Cosine Sim: 0.9736
# Epoch 104/200 | MSE Loss: 0.009046 | Masked Cosine Sim: 0.9735
# Epoch 105/200 | MSE Loss: 0.009036 | Masked Cosine Sim: 0.9736
# Epoch 106/200 | MSE Loss: 0.009042 | Masked Cosine Sim: 0.9736
# Epoch 107/200 | MSE Loss: 0.009026 | Masked Cosine Sim: 0.9736
# Epoch 108/200 | MSE Loss: 0.009025 | Masked Cosine Sim: 0.9736
# Epoch 109/200 | MSE Loss: 0.009025 | Masked Cosine Sim: 0.9736
# Epoch 110/200 | MSE Loss: 0.009020 | Masked Cosine Sim: 0.9736
# Epoch 111/200 | MSE Loss: 0.009031 | Masked Cosine Sim: 0.9736
# Epoch 112/200 | MSE Loss: 0.009012 | Masked Cosine Sim: 0.9736
# Epoch 113/200 | MSE Loss: 0.009017 | Masked Cosine Sim: 0.9736
# Epoch 114/200 | MSE Loss: 0.009005 | Masked Cosine Sim: 0.9737
# Epoch 115/200 | MSE Loss: 0.009016 | Masked Cosine Sim: 0.9736
# Epoch 116/200 | MSE Loss: 0.009016 | Masked Cosine Sim: 0.9736
# Epoch 117/200 | MSE Loss: 0.009010 | Masked Cosine Sim: 0.9737
# Epoch 118/200 | MSE Loss: 0.009015 | Masked Cosine Sim: 0.9736
# Epoch 119/200 | MSE Loss: 0.009006 | Masked Cosine Sim: 0.9737
# Epoch 120/200 | MSE Loss: 0.008997 | Masked Cosine Sim: 0.9737
# Epoch 121/200 | MSE Loss: 0.009005 | Masked Cosine Sim: 0.9737
# Epoch 122/200 | MSE Loss: 0.008997 | Masked Cosine Sim: 0.9737
# Epoch 123/200 | MSE Loss: 0.009000 | Masked Cosine Sim: 0.9737
# Epoch 124/200 | MSE Loss: 0.008999 | Masked Cosine Sim: 0.9737
# Epoch 125/200 | MSE Loss: 0.008996 | Masked Cosine Sim: 0.9737
# Epoch 126/200 | MSE Loss: 0.008999 | Masked Cosine Sim: 0.9737
# Epoch 127/200 | MSE Loss: 0.008993 | Masked Cosine Sim: 0.9737
# Epoch 128/200 | MSE Loss: 0.008994 | Masked Cosine Sim: 0.9737
# Epoch 129/200 | MSE Loss: 0.008989 | Masked Cosine Sim: 0.9737
# Epoch 130/200 | MSE Loss: 0.008988 | Masked Cosine Sim: 0.9737
# Epoch 131/200 | MSE Loss: 0.008977 | Masked Cosine Sim: 0.9737
# Epoch 132/200 | MSE Loss: 0.008974 | Masked Cosine Sim: 0.9737
# Epoch 133/200 | MSE Loss: 0.008977 | Masked Cosine Sim: 0.9738
# Epoch 134/200 | MSE Loss: 0.008973 | Masked Cosine Sim: 0.9738
# Epoch 135/200 | MSE Loss: 0.008975 | Masked Cosine Sim: 0.9738
# Epoch 136/200 | MSE Loss: 0.008979 | Masked Cosine Sim: 0.9738
# Epoch 137/200 | MSE Loss: 0.008974 | Masked Cosine Sim: 0.9738
# Epoch 138/200 | MSE Loss: 0.008973 | Masked Cosine Sim: 0.9738
# Epoch 139/200 | MSE Loss: 0.008966 | Masked Cosine Sim: 0.9738
# Epoch 140/200 | MSE Loss: 0.008970 | Masked Cosine Sim: 0.9738
# Epoch 141/200 | MSE Loss: 0.008961 | Masked Cosine Sim: 0.9738
# Epoch 142/200 | MSE Loss: 0.008970 | Masked Cosine Sim: 0.9738
# Epoch 143/200 | MSE Loss: 0.008961 | Masked Cosine Sim: 0.9738
# Epoch 144/200 | MSE Loss: 0.008964 | Masked Cosine Sim: 0.9738
# Epoch 145/200 | MSE Loss: 0.008959 | Masked Cosine Sim: 0.9738
# Epoch 146/200 | MSE Loss: 0.008960 | Masked Cosine Sim: 0.9738
# Epoch 147/200 | MSE Loss: 0.008956 | Masked Cosine Sim: 0.9738
# Epoch 148/200 | MSE Loss: 0.008955 | Masked Cosine Sim: 0.9738
# Epoch 149/200 | MSE Loss: 0.008953 | Masked Cosine Sim: 0.9738
# Epoch 150/200 | MSE Loss: 0.008951 | Masked Cosine Sim: 0.9738
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_150.png
# Epoch 151/200 | MSE Loss: 0.008957 | Masked Cosine Sim: 0.9738
# Epoch 152/200 | MSE Loss: 0.008953 | Masked Cosine Sim: 0.9738
# Epoch 153/200 | MSE Loss: 0.008945 | Masked Cosine Sim: 0.9738
# Epoch 154/200 | MSE Loss: 0.008947 | Masked Cosine Sim: 0.9738
# Epoch 155/200 | MSE Loss: 0.008944 | Masked Cosine Sim: 0.9738
# Epoch 156/200 | MSE Loss: 0.008942 | Masked Cosine Sim: 0.9739
# Epoch 157/200 | MSE Loss: 0.008951 | Masked Cosine Sim: 0.9738
# Epoch 158/200 | MSE Loss: 0.008941 | Masked Cosine Sim: 0.9739
# Epoch 159/200 | MSE Loss: 0.008940 | Masked Cosine Sim: 0.9739
# Epoch 160/200 | MSE Loss: 0.008939 | Masked Cosine Sim: 0.9739
# Epoch 161/200 | MSE Loss: 0.008930 | Masked Cosine Sim: 0.9739
# Epoch 162/200 | MSE Loss: 0.008941 | Masked Cosine Sim: 0.9739
# Epoch 163/200 | MSE Loss: 0.008938 | Masked Cosine Sim: 0.9739
# Epoch 164/200 | MSE Loss: 0.008938 | Masked Cosine Sim: 0.9739
# Epoch 165/200 | MSE Loss: 0.008937 | Masked Cosine Sim: 0.9739
# Epoch 166/200 | MSE Loss: 0.008931 | Masked Cosine Sim: 0.9739
# Epoch 167/200 | MSE Loss: 0.008938 | Masked Cosine Sim: 0.9739
# Epoch 168/200 | MSE Loss: 0.008933 | Masked Cosine Sim: 0.9739
# Epoch 169/200 | MSE Loss: 0.008931 | Masked Cosine Sim: 0.9739
# Epoch 170/200 | MSE Loss: 0.008934 | Masked Cosine Sim: 0.9739
# Epoch 171/200 | MSE Loss: 0.008929 | Masked Cosine Sim: 0.9739
# Epoch 172/200 | MSE Loss: 0.008925 | Masked Cosine Sim: 0.9739
# Epoch 173/200 | MSE Loss: 0.008928 | Masked Cosine Sim: 0.9739
# Epoch 174/200 | MSE Loss: 0.008937 | Masked Cosine Sim: 0.9739
# Epoch 175/200 | MSE Loss: 0.008935 | Masked Cosine Sim: 0.9739
# Epoch 176/200 | MSE Loss: 0.008930 | Masked Cosine Sim: 0.9739
# Epoch 177/200 | MSE Loss: 0.008919 | Masked Cosine Sim: 0.9739
# Epoch 178/200 | MSE Loss: 0.008925 | Masked Cosine Sim: 0.9739
# Epoch 179/200 | MSE Loss: 0.008931 | Masked Cosine Sim: 0.9739
# Epoch 180/200 | MSE Loss: 0.008923 | Masked Cosine Sim: 0.9739
# Epoch 181/200 | MSE Loss: 0.008921 | Masked Cosine Sim: 0.9739
# Epoch 182/200 | MSE Loss: 0.008919 | Masked Cosine Sim: 0.9739
# Epoch 183/200 | MSE Loss: 0.008918 | Masked Cosine Sim: 0.9739
# Epoch 184/200 | MSE Loss: 0.008924 | Masked Cosine Sim: 0.9739
# Epoch 185/200 | MSE Loss: 0.008922 | Masked Cosine Sim: 0.9739
# Epoch 186/200 | MSE Loss: 0.008912 | Masked Cosine Sim: 0.9739
# Epoch 187/200 | MSE Loss: 0.008922 | Masked Cosine Sim: 0.9739
# Epoch 188/200 | MSE Loss: 0.008920 | Masked Cosine Sim: 0.9739
# Epoch 189/200 | MSE Loss: 0.008920 | Masked Cosine Sim: 0.9739
# Epoch 190/200 | MSE Loss: 0.008929 | Masked Cosine Sim: 0.9739
# Epoch 191/200 | MSE Loss: 0.008921 | Masked Cosine Sim: 0.9739
# Epoch 192/200 | MSE Loss: 0.008925 | Masked Cosine Sim: 0.9739
# Epoch 193/200 | MSE Loss: 0.008921 | Masked Cosine Sim: 0.9739
# Epoch 194/200 | MSE Loss: 0.008924 | Masked Cosine Sim: 0.9739
# Epoch 195/200 | MSE Loss: 0.008928 | Masked Cosine Sim: 0.9739
# Epoch 196/200 | MSE Loss: 0.008919 | Masked Cosine Sim: 0.9739
# Epoch 197/200 | MSE Loss: 0.008927 | Masked Cosine Sim: 0.9739
# Epoch 198/200 | MSE Loss: 0.008920 | Masked Cosine Sim: 0.9739
# Epoch 199/200 | MSE Loss: 0.008920 | Masked Cosine Sim: 0.9739
# Epoch 200/200 | MSE Loss: 0.008915 | Masked Cosine Sim: 0.9739
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_200.png
#
# ✅ Pre-trained foundation weights successfully saved -> experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/smae_pretrained_model.pth

# %%
# ==============================================================
# CELL 6 – LEARNING CURVES PLOT & FINAL CHECKS
# ==============================================================
import matplotlib.pyplot as plt
import os

PLOT_DIR = os.path.join(OUTPUT_DIR, 'Report_Plots')
os.makedirs(PLOT_DIR, exist_ok=True)

# Create a figure with 2 subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
fig.suptitle('SMAE Pre-Training Performance Metrics', fontsize=16, fontweight='bold', y=1.05)

# --- Subplot 1: MSE Loss (Should go DOWN) ---
axes[0].plot(range(1, len(pretrain_losses) + 1), pretrain_losses, marker='o', color='red', markersize=4)
axes[0].set_title('Reconstruction Loss', fontsize=14)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Mean Squared Error (MSE)', fontsize=12)
axes[0].grid(True, linestyle='--', alpha=0.7)

# --- Subplot 2: Cosine Similarity (Should go UP towards 1.0) ---
axes[1].plot(range(1, len(pretrain_cos_sims) + 1), pretrain_cos_sims, marker='s', color='green', markersize=4)
axes[1].set_title('Shape Alignment (Cosine Similarity)', fontsize=14)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Cosine Similarity (1.0 = Perfect)', fontsize=12)
axes[1].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()

# Save the double plot in high resolution
curve_path = os.path.join(PLOT_DIR, 'PreTraining_Metrics_DoublePlot.png')
plt.savefig(curve_path, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

print(f"📈 Performance Metrics plot saved to: {curve_path}")
print("==============================================================")
print(" 🚀 PRE-TRAINING PHASE COMPLETELY FINISHED! READY FOR FINE-TUNING.")
print("==============================================================")
# Out:
# 📈 Performance Metrics plot saved to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Report_Plots/PreTraining_Metrics_DoublePlot.png
# ==============================================================
#  🚀 PRE-TRAINING PHASE COMPLETELY FINISHED! READY FOR FINE-TUNING.
# ==============================================================

# %%
# ==============================================================
# CELL 7 – POST-TRAINING EVALUATION (TropHY, DeepR, IMMUNO)
# ==============================================================
import torch
import numpy as np
import random

print("Selezione casuale di un nuovo set di spettri per la valutazione finale...")
# 1: TropHY, 2: DeepR, 4: TWIST, 5: IMMUNO
desired_sources_post = [1, 2, 4]
fixed_indices_post = []

for target_src in desired_sources_post:
    # Trova gli indici nel dataset con questa provenienza
    idx = np.where(dataset.sources == target_src)[0]
    if len(idx) > 0:
        # Sceglie un indice casuale, così puoi rieseguire la cella finché non trovi
        # gli spettri ideali (es. un DeepR più rumoroso)
        random_idx = np.random.choice(idx)
        fixed_indices_post.append(random_idx)

# Costruiamo i tensori
fixed_batch_post_list = []
fixed_sources_post_list = []

for idx in fixed_indices_post:
    x, y = dataset[idx]
    fixed_batch_post_list.append(x)
    fixed_sources_post_list.append(torch.tensor(y))

fixed_batch_post = torch.stack(fixed_batch_post_list)
fixed_sources_post = torch.stack(fixed_sources_post_list)

print(f"Spettri finali pronti! Provenienza: {[int(s) for s in fixed_sources_post]}")
print(f"Indici selezionati casualmente: {fixed_indices_post}")

# Assicuriamoci che il modello sia in modalità valutazione
model.eval()

# Chiamiamo la funzione di visualizzazione (passiamo PRETRAIN_EPOCHS come 'epoca' per il titolo e nome file)
visualize_progress(model, fixed_batch_post, fixed_sources_post, device, EPOCHS)
# Out:
# Selezione casuale di un nuovo set di spettri per la valutazione finale...
# Spettri finali pronti! Provenienza: [1, 2, 4]
# Indici selezionati casualmente: [15795, 247845, 309044]
# 📸 Plot saved successfully to: experiments/smae_pretrain/1000_pt/FingerPrint/Min-Max/exp_8/Reconstruction_Epoch_200.png
